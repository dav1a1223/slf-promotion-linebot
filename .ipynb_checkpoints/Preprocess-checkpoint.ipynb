# %%
from html.parser import HTMLParser
import json
import os
from os import listdir
import datetime
import operator

# %%
def load_json(file_name):
    with open(file_name) as f:
        data = json.load(f)
    messages = data['messages']
    new_st = [{k:(v.encode('iso-8859-1').decode('utf-8') if type(v) == str else v) for k, v in st.items()} for st in messages]
    new_st.sort(key=operator.itemgetter('timestamp'))
    return new_st

# %%
def preprocess(sorted_json):
    pre_time = 0
    all_docs = []
    doc = {}
    name = ''
    name_list = []
    content = ''
    QA_pair = {'from_doc':0,'pair':[]}
    QA_pairs = []
    doc_id = 0
    global owner_name
    for st in sorted_json:
        if('content' in st and '錯過了你的來電' in st['content']):
            continue
        if(st['timestamp']-pre_time > 1500):
            if(not doc == {}):
                doc['contents'].append({'sender_name':name,'content':content})
                doc['end_time'] = pre_time
                all_docs.append(doc)
    #             content = ''
            doc = {'id':doc_id,'contents':[],'start_time':st['timestamp']}
            doc_id += 1
    #         name = ''
        pre_time = st['timestamp']
        if('content' in st):
            if(st['sender_name'] == name):
                content += '\n' + st['content']
            else:
    #             content += 
                if(name == owner_name):
                    if(QA_pair['pair'] != []):
                        QA_pair['pair'].append(content)
                        QA_pairs.append(QA_pair)
                        QA_pair = {'from_doc':0,'pair':[]}
                else:
                    QA_pair['from_doc'] = doc_id-1
                    QA_pair['pair'] = [content]
    #             if(doc['contents'] != []):
                doc['contents'].append({'sender_name':name,'content':content})
                content = st['content']
                name = st['sender_name']
    return all_docs, QA_pairs

# %% [markdown]
# ## 記得改 data_path, output_path, owner_name
# ## QA_pairs: owner 有回答的問題跟答案，會說這個 pair 從第幾個 document 來，list 的第一個是 Q 第二個是 A
# ## all_docs: 把所有對話記錄根據 timestamp 差 1500 以上就切開切成一堆document，可以拿來做topic model

# %%
data_path = 'win/messages' #json檔案的位置
output_path = 'processed_messages/' #開一個資料夾放做好的檔案
QA_pair_size_threshold = 20 #要有幾個 QA pair 才做成檔案
all_folder_names = listdir(data_path)
for folder_name in all_folder_names:
    json_file = data_path + '/' + folder_name + '/message.json'
    owner_name = '吳乙瑩' #你的名字
    try:
        sorted_message = load_json(json_file)
    except:
        continue
    all_docs, QA_pairs = preprocess(sorted_message)
    if(len(QA_pairs) > QA_pair_size_threshold):
        with open(output_path+folder_name+'.docs','w') as f1:
            json.dump(all_docs,f1)
        with open(output_path+folder_name+'.pairs','w') as f1:
            json.dump(QA_pairs,f1)

# %%
file_name = 'processed_messages/'
pair_names = listdir(file_name)
all_num = []
for name in pair_names:
    if('pairs' in name):
        with open(file_name+name,'r') as f1:
            test = json.load(f1)
#             print(len(test))
            if(len(test)==13815):
                print(test)
            all_num.append([len(test),name])
# Out:
# [{'from_doc': 0, 'pair': ['妳開工了嗎', 'OAO  21號以前上船是否是否是否((緊張']}, {'from_doc': 0, 'pair': ['其實也不用這麼急啦', '今天烤肉有點開心-W-']}, {'from_doc': 0, 'pair': ['我也不確定我有沒有辦法\n哈哈', '我等等會做']}, {'from_doc': 0, 'pair': ['沒關係啦\n我也還沒開始', '裝什麼可愛XDDDDDDDDD']}, {'from_doc': 0, 'pair': ['沒有啦\n只是喜歡這套貼圖', '哈哈  不管就是在裝可愛xD\n哈哈超欠揍XD']}, {'from_doc': 0, 'pair': ['是看到我大頭貼吧\n哈哈哈哈', 'XDDDD\n開FB還想說這哪位xD\n哈哈你太有事了XD']}, {'from_doc': 0, 'pair': ['是有這麼誇張\n沒有啦哈哈\n沒事', '哈哈哈哈太閒吼XD']}, {'from_doc': 0, 'pair': ['只是覺得自己不帥又不可愛\n乾脆耍白癡', '這叫自暴自棄嗎XD']}, {'from_doc': 0, 'pair': ['妳直屬誰啊\n對了這幾天要多注意社團喔', '直屬是蕭志融學長\n你是說計概社團嗎?']}, {'from_doc': 0, 'pair': ['無人能敵之第一組\n喔喔', '噢噢噢噢噢!!\n好哦']}, {'from_doc': 0, 'pair': ['雷曜學姊有提到妳欸', 'WHEN !?']}, {'from_doc': 0, 'pair': ['今天早上', '噢噢  今早有活動噢!!']}, {'from_doc': 0, 'pair': ['因為她跟我同個社@@\n我密她', '真假!!!']}, {'from_doc': 0, 'pair': ['打個招乎\n烏克麗麗', 'WOOOW\nSOGA!']}, {'from_doc': 0, 'pair': ['要來嗎XDDDD', '我在數位影片創作社 B-)']}, {'from_doc': 0, 'pair': ['喔對噢\n忘了\nXD\n靖文有說', '摁摁他也是']}, {'from_doc': 1, 'pair': ['妳在做了嗎', '摁摁我再找圖我覺得我會用到一堆圖']}, {'from_doc': 1, 'pair': ['妳快用好\n先上傳\n這樣我就可以改了XD\n不然做最爛好丟臉', '什麼意思啦xDDDDDDDD']}, {'from_doc': 1, 'pair': ['我完全還沒開始', '那你要改什麼QAQ']}, {'from_doc': 1, 'pair': ['看妳做到怎樣的程度啊\n跟進', '噢可是我覺得我的字應該會很少']}, {'from_doc': 1, 'pair': ['喔對', '你的應該會圖文並茂A_A  或者文是重點之類的\n我主要是用說的吧感覺兒']}, {'from_doc': 1, 'pair': ['妳會加動畫\n嗯嗯嗯嗯嗯', '摁摁摁摁會']}, {'from_doc': 1, 'pair': ['我也是(狂點頭', '僅髒\nXD']}, {'from_doc': 1, 'pair': ['不用怕啦', '你的難度甚高~']}, {'from_doc': 1, 'pair': ['第一個是我欸==', '好嘔QAQ  有準備好就不會怕\n哈哈哈哈\nXDDD\n精神支柱!']}, {'from_doc': 1, 'pair': ['好遠', '好遠OAO?']}, {'from_doc': 1, 'pair': ['妳不是回台南？', '在台南了:)']}, {'from_doc': 1, 'pair': ['對啊\n好遠XDDDD', '哈哈哈噢噢噢xD']}, {'from_doc': 1, 'pair': ['妳有去南友嗎', '你們那邊現在在下雨嗎?\n會去吧雖說我至今沒參加過他們的動\n活動']}, {'from_doc': 1, 'pair': ['剛剛下午下很大', '不過會去烤肉\n是哦!!!\n我們晴朗欸~']}, {'from_doc': 1, 'pair': ['我知道\n我有線民\nXD', '哈哈哪來的!']}, {'from_doc': 1, 'pair': ['南友的\n她是書院跟我同小的XD\n也住台南', 'WOOOOW\n男生OR女生兒']}, {'from_doc': 1, 'pair': ['女生兒', '噢噢噢噢噢\n南女的嗎說不定我認識哦']}, {'from_doc': 1, 'pair': ['王禹晴', '噢噢噢噢']}, {'from_doc': 1, 'pair': ['？', '不認識\nXD']}, {'from_doc': 1, 'pair': ['認識！？\n喔喔喔==\n那還噢噢', '哈哈\n不是南女的吧!']}, {'from_doc': 1, 'pair': ['是吧', '是哦@"@\n糟糕人緣不好']}, {'from_doc': 1, 'pair': ['妳說她噢', '我啦']}, {'from_doc': 1, 'pair': ['哪會\n看妳讚都很多啊', '呃...  有些人就是看到什麼都案啊=ˇ=']}, {'from_doc': 1, 'pair': ['我的朋友就是看到了也不按啊', '哈哈哈\n那可能就是人品的問題了 A____A']}, {'from_doc': 1, 'pair': ['禮安是好人噢\n他有沒有密過妳啊？\n聊天', '算有吧\n這是哪迸出來的話題OAO!']}, {'from_doc': 1, 'pair': ['呵呵蒿\n其實這才是找妳的目的', '什麼啦!!!!\n前面再鋪路嗎OAO']}, {'from_doc': 1, 'pair': ['哈哈\n開玩笑的啦\n禮安是好朋友噢', '哈哈\n學姊還問過你跟鍾禮安是什麼關係XD']}, {'from_doc': 1, 'pair': ['知道啊\n靖雯有講', '對啊xD']}, {'from_doc': 1, 'pair': ['靖雯也是好朋友啊', '你好奇怪xD']}, {'from_doc': 1, 'pair': ['？@@\n蛤\n蛤？\n什麼奇怪\n而且妳那什麼意思', '很可愛的意思 <3']}, {'from_doc': 1, 'pair': ['妳很可愛？', '= " = 貼圖很可愛啦!!!!']}, {'from_doc': 1, 'pair': ['噢噢\n想說哪有人自己這樣講的\n不過雷曜學姊說妳很可愛', '-//-\n我也說他很可愛啊=ˇ=+']}, {'from_doc': 1, 'pair': ['噢噢哈哈', '自從他跟德國人對談後我就很崇拜他((眼睛閃閃']}, {'from_doc': 1, 'pair': ['是喔\n這麼猛', '用英文啦!']}, {'from_doc': 1, 'pair': ['也很強啊', '對啊超強\n流利的~']}, {'from_doc': 1, 'pair': ['My English is very poor\nTaiwanese English', "I don't believe you -w-"]}, {'from_doc': 1, 'pair': ['XD', '噢噢me 2']}, {'from_doc': 1, 'pair': ['大概講出來跟管數老師一樣\n哈哈可能好一點', '哈哈哈我也是啦就是會有台灣腔難過難過QQ\n而且無法講很快']}, {'from_doc': 1, 'pair': ['嗯嗯\n欸對喔\n我們國文課一起欸\n哈哈\n雖然不同組', '真假!!!']}, {'from_doc': 1, 'pair': ['開社團(誤', 'xD\n我跟賴冠廷還有一個資管的我好像不太認識的人一組@"@']}, {'from_doc': 1, 'pair': ['==\nㄜ什麼星座的', '呃.... 不知道欸就風象的OAO\n賴冠廷應該知道囧']}, {'from_doc': 1, 'pair': ['我想想\n不知道\n哈哈', '-.-+']}, {'from_doc': 1, 'pair': ['妳國文課都自閉自閉的', '哪有\n你說坐在角落的關係嗎']}, {'from_doc': 1, 'pair': ['對啊', '哈哈啊我就不認識你們啊\n而且座牆邊可靠牆=ˇ=\n而且我不喜歡國文']}, {'from_doc': 1, 'pair': ['誰喜歡啊==\n誰叫妳不去宿營\n哈哈哈哈', '吼!!!!\n我也想去啊!!!!']}, {'from_doc': 1, 'pair': ['不過妳沒來也是有被討論喔\n？', '真假啊可是還是不認識啊而且我超不會記名字的\n尤其又只有我一個台南人\n好可憐兒']}, {'from_doc': 1, 'pair': ['哪會\n現在不都不錯了', '我覺得應該是我比較懶的關係吧:"目\n還好欸還是很多不認識的']}, {'from_doc': 1, 'pair': ['那我是誰妳知道嗎', '斯.................................\n((眉頭深鎖']}, {'from_doc': 1, 'pair': ['== ...

# %%
import operator

# %%
all_num.sort(key=operator.itemgetter(0))
all_num.reverse()

# %%
all_num
# Out:
# [[58811, 'chenhongzhi_c43c078b40.pairs'],
#  [13815, 'lishangen_a3430f03e0.pairs'],
#  [12154, 'jhihbanghsieh_25e09d0c14.pairs'],
#  [7186, 'zhangyongran_2e6a77d325.pairs'],
#  [6820, 'cengyunhan_5c49ffe116.pairs'],
#  [6720, 'luoyunling_0cdf03bd91.pairs'],
#  [6703, 'yirutsai_4057ffc580.pairs'],
#  [6303, 'heweihong_a72413184a.pairs'],
#  [5235, 'chouchouhu_96f9e57be4.pairs'],
#  [4456, 'tujingwen_8b0f538c6b.pairs'],
#  [4151, 'zhoujiapei_4e8b5cdaa0.pairs'],
#  [3985, 'facebookyonghu_f205e4f898.pairs'],
#  [3793, 'zhenghuiwen_707ae26128.pairs'],
#  [3637, 'maermogaizhiwenikeabanriyou_b9e1249a43.pairs'],
#  [3457, 'chenshaoen_2b13ff7983.pairs'],
#  [3428, 'facebookyonghu_b352216b61.pairs'],
#  [3288, 'zhuyaozhang_923e480f67.pairs'],
#  [2805, 'guoyutang_97ad441951.pairs'],
#  [2599, 'rongerhuang_904f618e87.pairs'],
#  [2344, 'lujungwang_544431869c.pairs'],
#  [2304, 'kangshihong_bb5013a09d.pairs'],
#  [2297, 'dayizongshidaikebushimalinkououtletwufahuiwei_1d010cbd95.pairs'],
#  [2270, 'liqinghong_5000d14777.pairs'],
#  [1996, 'chenweiting_48b2c29720.pairs'],
#  [1780, 'chenbaixuan_f837f08e74.pairs'],
#  [1759, 'wangzhihao_58f6b6f7f3.pairs'],
#  [1655, 'linruian_77c018f0cf.pairs'],
#  [1594, 'liyixuan_77b8d8bc42.pairs'],
#  [1558, 'liuguanhong_bb235a8b3f.pairs'],
#  [1447, 'laiguanting_11f5cdb435.pairs'],
#  [1382, 'haojianqiang_ef0db02800.pairs'],
#  [1289, 'ziguanyingdaoshu8yuezongfuzhao_f875ca2ad0.pairs'],
#  [1164, 'fangsongying_e68f6acd05.pairs'],
#  [1161, 'wangzijia_ca86427cbf.pairs'],
#  [1068, 'hongleiyao_d8050052f3.pairs'],
#  [1062, 'wangyuwei_7482d3e1e9.pairs'],
#  [1004, 'lianghuiyi_2e3a6aa12c.pairs'],
#  [982, 'jiangmengxuan_c434683ccb.pairs'],
#  [977, 'nulanleileilei_7a01cb3bf0.pairs'],
#  [973, 'mingcianhong_fdc32b067e.pairs'],
#  [972, 'tsaipingkuo_89da174a2e.pairs'],
#  [963, 'buyaozaichangshangpaishouaziguannulan_bed4229fcf.pairs'],
#  [957, 'hongnianqi_bbe72da15e.pairs'],
#  [947, 'chenjunru_25d2c1fffa.pairs'],
#  [923, 'songxinxin_54b4a18127.pairs'],
#  [911, 'zhonglian_9a9ed0133a.pairs'],
#  [902, 'caixiankui_a05a05bdd8.pairs'],
#  [880, 'tingshuojinnianguanyuanziguanbeizibeiyaonajiangbei_5d169cb716.pairs'],
#  [868, 'sufangyu_8799166f1c.pairs'],
#  [861, 'mengdianwu_331c810cef.pairs'],
#  [819, 'linshuyou_0f0885bd01.pairs'],
#  [790, 'chuyunchiang_b99d2212a4.pairs'],
#  [780, 'ninawu_db53bdedae.pairs'],
#  [775, 'xiaozhirong_f363043b2d.pairs'],
#  [746, 'wanzhenyan_db7c0a8862.pairs'],
#  [743, 'xieyilun_cc4c228a46.pairs'],
#  [727, 'winziband_4fe9ca5c47.pairs'],
#  [722, 'lutingxuan_b9e650316d.pairs'],
#  [697, 'linhanshen_99f9d2a5f8.pairs'],
#  [683, 'yangtianyi_8809d5ae07.pairs'],
#  [649, 'linyishu_9d1f4047d6.pairs'],
#  [635, 'shiyingkang_b22f7c5699.pairs'],
#  [633, 'linyujie_9bc5595b16.pairs'],
#  [609, 'chenxinyi_0fb81e84aa.pairs'],
#  [576, 'yuxianghao_dc04f58bd8.pairs'],
#  [566, 'mis_ca202b6035.pairs'],
#  [551, 'jianminyu_37c956cc6c.pairs'],
#  [550, 'chenliangcheng_2f0276887b.pairs'],
#  [537, 'yewenjie_dc22256ef0.pairs'],
#  [522, 'zhegecaishigongguan_56df98d8e3.pairs'],
#  [499, 'renmatsuki_0f352cc3b4.pairs'],
#  [493, 'tushigtse_22bd5b6be6.pairs'],
#  [492, 'heyiqing_fe4b9c7da2.pairs'],
#  [491, 'zhengfuduizhangxiaoquanquan3_c407608477.pairs'],
#  [485, 'buyaocuopin_5b7874ee25.pairs'],
#  [468, 'chenyuanrui_a8638b75bf.pairs'],
#  [457, 'xieyuping_e1ccb00e1d.pairs'],
#  [452, 'chrisgerrard_c498d0a03d.pairs'],
#  [441, 'tingyushen_66718ac7ac.pairs'],
#  [440, 'wuzhongyan_691d294385.pairs'],
#  [425, 'cengziting_4e415ed53e.pairs'],
#  [424, 'daijiaze_3baf01f652.pairs'],
#  [418, 'yangdongying_c246880f45.pairs'],
#  [414, 'xuanchuanbu_0f25ef5038.pairs'],
#  [414, 'erikashimizu_4bb09d462c.pairs'],
#  [408, 'wangyuxin_d3eae7a804.pairs'],
#  [403, 'liutingxuan_ded4a28d45.pairs'],
#  [402, 'wangzijiahelinbaiheng_53ee1044db.pairs'],
#  [394, 'karmachang_db028caf1f.pairs'],
#  [394, 'wangmengqi_cd4608971d.pairs'],
#  [388, 'facebookyonghu_b2b4f3e83a.pairs'],
#  [387, 'xupinhan_a278b75a75.pairs'],
#  [382, 'wuyaxuan_5bcca66ccd.pairs'],
#  [377, 'chashaobaidi_2410621fea.pairs'],
#  [371, 'permanentnuwushen_7d5ee699ec.pairs'],
#  [364, 'zhangjunmao_852a1e4628.pairs'],
#  [360, 'qiugeitiantian_6911f577d5.pairs'],
#  [351, 'zhangbocheng_4a55bbbc6e.pairs'],
#  [348, 'facebookyonghu_0fc91d2101.pairs'],
#  [348, 'duifuzhang_fa40877895.pairs'],
#  [343, '491684eb61.pairs'],
#  [341, 'xingguan555555_0eeacbe154.pairs'],
#  [339, 'huodongbu_b52c026e02.pairs'],
#  [325, 'webirtaolunkuang_e74de5fe2a.pairs'],
#  [324, 'renatoplacienterobedizo_3bab0a8044.pairs'],
#  [317, 'lengjunying_f1af39ec6d.pairs'],
#  [315, 'cengyunhanhehuangyuhan_ea3f43337a.pairs'],
#  [311, 'richardhuang_5259215fa4.pairs'],
#  [310, 'lynnlin_944012761c.pairs'],
#  [310, 'jennylin_37fa458779.pairs'],
#  [308, 'wangyuqing_0f8b407731.pairs'],
#  [307, 'cyriaquebruez_c473eee092.pairs'],
#  [307, 'laorenbang_ea108574e7.pairs'],
#  [305, 'xiezonghan_a9654e0023.pairs'],
#  [297, 'liaoyishan_fabd43e614.pairs'],
#  [292, 'laitingan_e37b044cfa.pairs'],
#  [291, 'muenlee_e109c711d0.pairs'],
#  [279, 'shouyuju_b1ceb3e335.pairs'],
#  [279, 'xiedanwen_6e47cf1f3d.pairs'],
#  [279, 'ruangongdierzu_7a18e6fcbc.pairs'],
#  [276, 'wuxuxuan_e70ef1e65b.pairs'],
#  [275, 'zhangjunmaoguoyutanghechenhongzhi_d644cc937c.pairs'],
#  [270, 'guozhuni_493838fa17.pairs'],
#  [264, 'chenhongwei_c59825dad6.pairs'],
#  [257, 'zhangzhicong_087827b330.pairs'],
#  [255, 'chenmuci_1a3b373012.pairs'],
#  [255, 'yukikochi_5edfa71031.pairs'],
#  [255, 'huangyuhan_5e5c1bfdb5.pairs'],
#  [253, 'liuyuting_98f30020d0.pairs'],
#  [248, 'zhangweirong_c4487e5621.pairs'],
#  [247, 'xuxuanmin_61adbbc2cf.pairs'],
#  [238, 'guoyanping_c4a754e380.pairs'],
#  [237, 'mingcianhongtsaipingkuohezhoujiapei_e920a74c9d.pairs'],
#  [232, 'ziguancaijinhaopengyou_4fda8bc225.pairs'],
#  [230, 'chenjunruheliuyunhao_466c227bfd.pairs'],
#  [229, 'zhangweifan_832c55a89f.pairs'],
#  [218, 'huberthuang_f7e1c0e165.pairs'],
#  [215, 'dongyuru_01294ba800.pairs'],
#  [210, 'dengzhengwen_2159842d13.pairs'],
#  [209, 'likunpu_ccb1b11063.pairs'],
#  [208, 'yingwenxiaozu_b13267fa42.pairs'],
#  [206, 'bilab2018_4586209a63.pairs'],
#  [205, 'linnianying_7822ce88f6.pairs'],
#  [205, 'dorcyyang_4eb47b6096.pairs'],
#  [204, 'xuzheming_0ed781d11e.pairs'],
#  [203, 'ouaqimo_59d3e210ad.pairs'],
#  [201, 'xieyupingchenxinyizhenghuiwenheqita5ren_7855cb4468.pairs'],
#  [200, 'zuoguan_edd240cc27.pairs'],
#  [197, 'soominkim_9caf9935b7.pairs'],
#  [195, 'yangzhiwei_002e80f88d.pairs'],
#  [195, 'wenglao__jingzhengcee_c0763afc87.pairs'],
#  [195, 'appzhanshi_8de1d693aa.pairs'],
#  [195, 'jigaiyaochaojilihaideyingpiangongzuotuandui_c2e3a57818.pairs'],
#  [194, 'zhangjinhua_2f7d8be599.pairs'],
#  [192, 'fangstefan_dae3f291da.pairs'],
#  [191, 'zhiyedasanband_6703e546ea.pairs'],
#  [188, 'huangchuting_654edf568e.pairs'],
#  [187, 'lujiuliu_3fa43d23b4.pairs'],
#  [185, 'nanzihan_dcbd053eb8.pairs'],
#  [183, 'yiyangwang_cbf9eb3721.pairs'],
#  [182, 'yangdawei_bcd30b8fc4.pairs'],
#  [181, 'weidadejiadayimen_b39043281c.pairs'],
#  [179, 'talimuaisbalavi_9abdf09ada.pairs'],
#  [177, 'jililing_521c7757fc.pairs'],
#  [169, 'mistaolunshi_25815e1249.pairs'],
#  [169, 'wangtiantian_0c55a801b9.pairs'],
#  [169, 'shuweiyingxiangchulisanrenxing_feeb71ab56.pairs'],
#  [166, 'wengyizong_b1b7b75ccb.pairs'],
#  [165, 'huangliwen_df23a9bfeb.pairs'],
#  [162, 'xintingshuomingtianhedahoutianyousangerenyaoshengri_9cfe39c93d.pairs'],
#  [162, 'liweici_298eae82e8.pairs'],
#  [160, 'takumaarai_19d750e182.pairs'],
#  [160, 'linpinrong_5150d440dc.pairs'],
#  [157, 'leiisun_ad9c4adbf7.pairs'],
#  [156, 'kunchongyulunshen_aac6fce009.pairs'],
#  [152, 'orqqqqqq_168f156c5f.pairs'],
#  [151, 'womenyaohuizongqure_d51a8f5bd5.pairs'],
#  [147, 'zhangsiyu_c643fe936e.pairs'],
#  [146, 'xuyiran_4861dd9d8c.pairs'],
#  [146, 'zhangyihan_f372479afb.pairs'],
#  [143, 'linmeixuan_ba0da42d4c.pairs'],
#  [142, 'linjingjie_e6953a00e5.pairs'],
#  [141, 'laixuanzhu_2b2fb25176.pairs'],
#  [141, 'ziyin_66a873ce3f.pairs'],
#  [140, 'wengruixin_f2a6a0267b.pairs'],
#  [139, 'xinshengbeinulanwenxinxiaokuangkuang_20f17bdff2.pairs'],
#  [139, 'yichencheng_1281a16650.pairs'],
#  [137, 'weiyujie_f1e85a8759.pairs'],
#  [136, 'wuyiyingshidaxiangchaoren_ae3627cc4e.pairs'],
#  [136, 'taibeibang_7cc6fd5228.pairs'],
#  [132, 'yutingyi_baef663bcd.pairs'],
#  [130, 'zhiyerockkanongyo_85e520d425.pairs'],
#  [130, 'huangzhexuan_e6b6f14b30.pairs'],
#  [128, 'huangxi_09c0146820.pairs'],
#  [127, 'xujingchun_26fe71f310.pairs'],
#  [126, 'teslashih_1d705072a4.pairs'],
#  [125, 'cengziyu_b4c79be4a4.pairs'],
#  [124, 'shaoendechulianqingren_08de12c2c5.pairs'],
#  [124, 'zhangyupeng_7a0579b881.pairs'],
#  [123, 'zhengliwei_e03fd0b183.pairs'],
#  [120, 'lylyegg_0f1d4c4216.pairs'],
#  [119, 'nulanyaosongzoulaorenlekuku_e355d28d64.pairs'],
#  [117, 'jiaweishen_f08bbece7f.pairs'],
#  [116, 'karaokeniikimashou_7758ccd8e5.pairs'],
#  [114, 'xujiaqi_125ace0791.pairs'],
#  [114, 'linguanying_8fdd70f3b0.pairs'],
#  [114, 'linbaiyin_1ed2a71928.pairs'],
#  [111, 'zhongxietujingwenkapianjihua_8c3d7773ac.pairs'],
#  [110, 'nanyegongguanqianduoduo_ab053ace44.pairs'],
#  [109, 'wujianxia_3689b5b0a1.pairs'],
#  [109, 'yucaiting_750b86c137.pairs'],
#  [106, 'taijiaoyouhao_ef9be2adb4.pairs'],
#  [105, 'hongnianqiwuxuxuanhexiaozhirong_0e0ab48f44.pairs'],
#  [104, 'jianglijia_e3a49d3cbc.pairs'],
#  [104,
#   'mingcianhongtsaipingkuozhoujiapeihespringklostergarden_4fe94559fa.pairs'],
#  [104, 'zhengyouquan_47ac9f2fa6.pairs'],
#  [104, 'datamining_74cea5d9c1.pairs'],
#  [103, 'chenyijie_a1379edbd4.pairs'],
#  [102, 'johanmartensson_e85feef65e.pairs'],
#  [102, 'haosiqiao_4cfc260d1e.pairs'],
#  [100, 'chenxuanxuan_7abe9e5d03.pairs'],
#  [99, 'chenyunjing_acbb30f5b4.pairs'],
#  [97, 'yangyujia_a307024eb2.pairs'],
#  [97, 'zhuangjunzhi_f6832cbe75.pairs'],
#  [96, 'cengbaoyi_bfa3f10f2d.pairs'],
#  [95, 'zhenjingqianwanrendeimzhiyedaerdasanband_a90b2c8c11.pairs'],
#  [93, 'linjunyu_6ed298c861.pairs'],
#  [92, '16503_902e1e84df.pairs'],
#  [92, 'guoyutanghechenhongzhi_df49f0c966.pairs'],
#  [90, 'linyuqin_e378d96d51.pairs'],
#  [90, 'yedawei_b65e1e4786.pairs'],
#  [90, 'kehanyu_48f0aeeceb.pairs'],
#  [90,
#   'baoganzhiyexuanchuanpianqirixiaozujianzhibichuangshijihaicheai_2bd5526ba0.pairs'],
#  [89, 'wangbaiting_25646fc33b.pairs'],
#  [87, 'meixuanbu_2cabf5d53c.pairs'],
#  [86, 'xiaopingguo_52a412995e.pairs'],
#  [86, '1222fridaysshengdanjucanmeihuidedousuan_9b20eef80f.pairs'],
#  [85, '2015nanyegongguan_254e157817.pairs'],
#  [85, 'facebookyonghu_f942cf8acd.pairs'],
#  [84, 'liuyunhao_67daa0b1bc.pairs'],
#  [84, 'linshixin_19ef827725.pairs'],
#  [84, 'johnnytran_7286ccdb9a.pairs'],
#  [82, 'guoyutanglaiguantinghechenhongzhi_f50dffef8d.pairs'],
#  [80, 'siyuenodeguo_08a3073c1d.pairs'],
#  [79, 'youjunhui_b5801a0f71.pairs'],
#  [79, 'wanglizhen_1beff9b7bc.pairs'],
#  [77, 'wangrenhongjennytsaiheyucaiting_95af44595b.pairs'],
#  [77, 'zuozhanjihua_aa32f6f105.pairs'],
#  [77, '5yatianqiangpiaotuan_ee0c3bdef4.pairs'],
#  [77, 'konglingjie_b433b6183d.pairs'],
#  [76, 'meiyouhongjundebiailaibxd_417c5ac898.pairs'],
#  [75, 'nulan0830songjiu_dde1b8ca2c.pairs'],
#  [72, 'bingdaoziyouxing_6f3da8ae51.pairs'],
#  [72, 'erzub02_ea282539a2.pairs'],
#  [72, 'facebookyonghucengyunhandengzhengwenheqita5ren_7c6fb30425.pairs'],
#  [72, 'tiantianhaoxiangni_119b3417d5.pairs'],
#  [72, 'shuwu_ba7dc27254.pairs'],
#  [71, 'xubocheng_aa240b7784.pairs'],
#  [70, 'jianyiruchenxinyizhenghuiwenheqita4ren_2a0747569d.pairs'],
#  [70, 'linqiyou_d485d542f5.pairs'],
#  [70, 'linchengwei_cfa5e56699.pairs'],
#  [69, 'shuwubu_37de6ca83d.pairs'],
#  [69, 'hacklemaxdddd_efb4e4e990.pairs'],
#  [68, 'hsuanjungchou_609767712e.pairs'],
#  [68, 'ziguandeweilai_c43da29ae0.pairs'],
#  [68, 'wupeixuan_e01f47fd31.pairs'],
#  [68, 'xiecaixuan_a335551c23.pairs'],
#  [67, 'zhuyaozhangchenjunruhezhonglian_881ff5cc7c.pairs'],
#  [67, 'wangshicheng_87a1dc5aa8.pairs'],
#  [67, 'cengyuchen_6baaff0b61.pairs'],
#  [67, 'fanyunmiao_6518cd8764.pairs'],
#  [66, 'baileidegushiyihouyaobanlinyishu_05c5934c87.pairs'],
#  [66, 'yewenjiehongleiyaohezhenghuiwen_0232f306c2.pairs'],
#  [66, 'wuwanyu_b1fc3c825c.pairs'],
#  [66, 'dairuyi_073c428971.pairs'],
#  [64, 'linyuwei_498a2a58bb.pairs'],
#  [64, 'gexuan_3576ebf257.pairs'],
#  [64, 'xuxiaoyakangshihongyedaweihexuzheming_49e8887907.pairs'],
#  [64, 'liyuxian_1eeafc25af.pairs'],
#  [64, 'springklostergarden_1e78aa3dc4.pairs'],
#  [63, 'caiyunyun_2e8d88bcd2.pairs'],
#  [63, 'paulinelu_cadce693f8.pairs'],
#  [63, 'victoriachiu_1018b2caf7.pairs'],
#  [62, 'jinjitongjitaolun_53c7d568b9.pairs'],
#  [62, 'chaojungchang_78136de755.pairs'],
#  [62, 'cengzitingcengyunhandengzhengwenheqita4ren_fdaa959706.pairs'],
#  [62, 'harenatseng_ea9219c5b3.pairs'],
#  [61, 'qianqianxing_a80e462cd7.pairs'],
#  [61, 'shequnzhongdeshaonuxd_95d4c7498e.pairs'],
#  [61, 'linzhiyu_f5cbb26c50.pairs'],
#  [61, 'tingshuoyunlingmingtianshengrihahahaha_be5075d0b3.pairs'],
#  [60, 'buxiangdadui_2837baa30f.pairs'],
#  [60, 'orcasestudy2_a04cdd3ff7.pairs'],
#  [60, 'sabinacheng_bf9dc01f20.pairs'],
#  [59, 'wengjingya_1227a827ad.pairs'],
#  [58, 'laipinxuan_348d94dcc2.pairs'],
#  [58, 'facebookyonghu_1e8b503255.pairs'],
#  [57, 'wuqiaoling_791af70dca.pairs'],
#  [56, 'zhuyaozhangchenshaoencaixiankuiheheweihong_dc023818cd.pairs'],
#  [56, 'yichiliao_44420c48d5.pairs'],
#  [56, 'liqinghongtujingwenwanzhenyanhechenhongzhi_4f4a36ffbc.pairs'],
#  [55, 'nulanxiaopengyousongweitingluo_fabd20b969.pairs'],
#  [55, 'chenyici_6cf7035e7f.pairs'],
#  [55, 'chiaicheng_0f23434818.pairs'],
#  [55, 'linwenhao_f72c8c6883.pairs'],
#  [54, 'xuxiaoya_5fb29b9958.pairs'],
#  [54, 'wudianbantanglaoyabendanyiying_e2e6dccfaf.pairs'],
#  [53, 'rudylin_addd7e2a9b.pairs'],
#  [53, 'caimengshan_24f5291a10.pairs'],
#  [53, 'linyizhen_fdc610329d.pairs'],
#  [53, 'jeroyu_51ff2459dd.pairs'],
#  [52, 'ziguanbei422libaiwuxiatainan_752ad4a6e0.pairs'],
#  [52, 'wangruoxin_e417796d3b.pairs'],
#  [52, 'xinshengbeigayibo_a0e6ca7a15.pairs'],
#  [52, 'chenxingyu_4ae4a2e56f.pairs'],
#  [52, 'dexiaweijifenjucanluo_d76d12493f.pairs'],
#  [52, 'facebookyonghuhesufangyu_dac89afa82.pairs'],
#  [51, 'weiyumei_711fa9483f.pairs'],
#  [51, 'guoyutong_af294c1d75.pairs'],
#  [50, 'marcusandersson_e13ba788f7.pairs'],
#  [50, 'kechengbu_60b62c5831.pairs'],
#  [50, 'ziguanxinshengbeinulan_bee14b1052.pairs'],
#  [50, 'maihirokawa_9b43975f44.pairs'],
#  [50, 'lolxijibeihanshensuanzongtong_2ff22c753d.pairs'],
#  [49, 'erzuxiaoquanquan_65613193cb.pairs'],
#  [49, 'annaforssellfragides_32465ae8a8.pairs'],
#  [49, 'linyiting_bd821486f6.pairs'],
#  [48, 'ganbuju_9714d8a551.pairs'],
#  [48, 'jennytsai_82d917ff91.pairs'],
#  [47, 'xiaohonglin_12a3c4ef73.pairs'],
#  [47, 'gengwang_34189e0543.pairs'],
#  [47, 'alicechang_2d9e0a4127.pairs'],
#  [47, 'guojiru_5543cf292d.pairs'],
#  [47, 'weiyujiechenxinyihezhenghuiwen_d6a464a6e4.pairs'],
#  [47, 'hongpeixuan_43da46b685.pairs'],
#  [46, 'xuyiqin_99cdc95fba.pairs'],
#  [46, 'kuaniangogo_95e6e60191.pairs'],
#  [46, 'huangqiyou_2f682746ce.pairs'],
#  [46, 'xiehuiyu_5e96dd2d29.pairs'],
#  [45, 'cengyunhanhelutingxuan_ab4424ea96.pairs'],
#  [45, 'huoyu_5e5d9b81a7.pairs'],
#  [45, 'gaoweili_d0ff940510.pairs'],
#  [44, 'chenpinjie_ec1798aed4.pairs'],
#  [44, 'ellenwu_6b597088fa.pairs'],
#  [43, '1314kuaniantaolunqu_7325ca3da7.pairs'],
#  [43, 'jinyanru_7a0e85d7fb.pairs'],
#  [43, 'zhengyunqi_207da19c8f.pairs'],
#  [42, 'xinjidexieajianshengrikapian_376ddcf011.pairs'],
#  [42, 'nayeonkim_34a40b74de.pairs'],
#  [41, 'wuxinan_46a1eb6a2e.pairs'],
#  [41, 'liqiwei_fd67cd705e.pairs'],
#  [41, 'caiyiqin_685533ad5a.pairs'],
#  [41, 'cengyunhanheyangshuting_1666cea70b.pairs'],
#  [41, 'liyizhen_1911388de0.pairs'],
#  [41, 'zheshimeiyou1rugenshaoyudeshengriduihuakuang_739b8d2b2f.pairs'],
#  [41, 'hualianlinyishujia_03ae704634.pairs'],
#  [41, 'wuhaoping_ad6d598b24.pairs'],
#  [41, 'xiaoyouliang_c05ff5de43.pairs'],
#  [40, 'kangshihongyedaweihexuzheming_3e2252fb0a.pairs'],
#  [40, 'chenaiguo_d7d9af0165.pairs'],
#  [40, 'chenyizhen_b64f670f08.pairs'],
#  [40, '31haojia109wan1016wanzeyirilaijiajuba_8b6f3bee51.pairs'],
#  [39, 'chenzhenling_09535b5473.pairs'],
#  [39, 'amoshsiao_d18864048a.pairs'],
#  [38, 'wobuhuixigoushuihuixigou_98dee97f5b.pairs'],
#  [38, 'tingyushenxieyupingchenweitingheqita5ren_7b3db7c2b2.pairs'],
#  [38, 'zongyoushuoyaosongxuezhangjiexiaoji_452c99b33b.pairs'],
#  [37, 'jitashoubeisishougushou_de79ec4166.pairs'],
#  [37, 'zhaoxinyi_ac5699473b.pairs'],
#  [36, 'jianminyuchenshaoenjiangmengxuanheqita2ren_7c8dce9770.pairs'],
#  [36, 'melodytrinhmingcianhongyukikochiheqita5ren_d52d72ed43.pairs'],
#  [36, 'yixiawuorerwanhanguohuoche_e482ab8b0e.pairs'],
#  [36, 'zhangyuzhen_416a970c15.pairs'],
#  [35, 'lishangenhetujingwen_71a6ea6457.pairs'],
#  [35, 'wangsiqi_b0529dc49d.pairs'],
#  [35, 'yanhaomin_6249963b8d.pairs'],
#  [35, 'huangyunjing_e3490c880a.pairs'],
#  [35, 'jirong_e28ced3a35.pairs'],
#  [35, 'jianghuiwen_f7647c5bd6.pairs'],
#  [34, 'wangmanyu_293457c1f9.pairs'],
#  [34,
#   'nulanwenxinguangboshilianqiu925si1830xinshengqiuchang_fabcccd6b9.pairs'],
#  [34, 'shuyoushengrile_86119c6392.pairs'],
#  [34, 'kuaqilai_be5131739b.pairs'],
#  [34, 'zhuyaozhangheguoyutang_a3e900b3e2.pairs'],
#  [34, 'kaichangyingpian_9fb52108cf.pairs'],
#  [34, 'yangpeirong_5d2c0fbd1c.pairs'],
#  [33, 'zhangnaiwen_5ed3ff1fc8.pairs'],
#  [33, 'hungchunfang_a1d54b4b0a.pairs'],
#  [33, 'ziguanyingduifulala_8ef34e9a1d.pairs'],
#  [33, 'zhenghanqin_431d89befe.pairs'],
#  [33, 'zhengchunwen_8c3b93797f.pairs'],
#  [33, 'minayu_cea6cbbf60.pairs'],
#  [32, 'zhanyuzhen_72f400540d.pairs'],
#  [32, 'lijinlin_0640023b6d.pairs'],
#  [32, 'henggemo_9cdb668fb5.pairs'],
#  [32, 'yangyanru_2818c0b9d1.pairs'],
#  [31, 'wuzhuyun_0fe1f09da8.pairs'],
#  [31, 'xushaoxuan_fa0ddf5ecd.pairs'],
#  [31, 'cengyunhanhefacebookyonghu_027e471b94.pairs'],
#  [31, 'hsupuhsin_959e24817a.pairs'],
#  [31, 'chenyingtao_712f3d24ad.pairs'],
#  [31, 'zhuwenling_6268b801da.pairs'],
#  [30, 'seanliao_e2e0166027.pairs'],
#  [30, 'taidaziguan_6e0c142998.pairs'],
#  [30, 'zhuantaozijiuhuidaoshuyigeyue_cacb8758fc.pairs'],
#  [30, 'caiqifang_ea15c1ce01.pairs'],
#  [30, 'linshijun_579c6f9f8d.pairs'],
#  [30, 'chentaiting_527d764fa1.pairs'],
#  [30, 'ninishengriluo_f904eeff52.pairs'],
#  [30, 'xingqiwuxiawuzhuantaowannidemingzi_8aefc3e956.pairs'],
#  [30, 'qqheyinhaishiheyin_05134cc36b.pairs'],
#  [30, 'cengjianxun_6898d10658.pairs'],
#  [29, 'stanleylin_663e6a5e95.pairs'],
#  [29, 'wuyien_74336328fd.pairs'],
#  [29, 'wuguanda_d787790f8a.pairs'],
#  [29, 'elliejohnsontsaipingkuozhoujiapeiheambreandrm_b911aaaee5.pairs'],
#  [29, 'linjingjiehewanzhenyan_a3c238744f.pairs'],
#  [29, 'wuishuen_0a4499cda8.pairs'],
#  [29, 'wulijun_2aa9496d8c.pairs'],
#  [29, 'cailing_c36104cd79.pairs'],
#  [29, 'wupeixuantujingwenhechenhongzhi_8522910ccc.pairs'],
#  [29, 'huyizhen_8157d6685e.pairs'],
#  [29, 'rayuchang_3cc61aca56.pairs'],
#  [29, 'jiantaoruangong_2b39bb2d13.pairs'],
#  [28, 'xinshijie_89d258c2f1.pairs'],
#  [28, 'yingxinsuyingsaimaer_574062250b.pairs'],
#  [28, 'anassq_79bd255406.pairs'],
#  [28, 'tingshuo48jialianggeerenyaoshengrile_78b29d5d5c.pairs'],
#  [28, 'yirenyizuoyejiujiuwuyiying_33724d9544.pairs'],
#  [28, 'linhaoxiang_b9204c5cd8.pairs'],
#  [28, 'jennakwok_26b5038726.pairs'],
#  [27, 'facebookyonghu_4d610cfb8c.pairs'],
#  [27, 'huansongkabu_5cb3043bed.pairs'],
#  [27, 'hongjunyang_e86b0749e4.pairs'],
#  [27, 'im106nushengxiaoquanquan_bb18d12494.pairs'],
#  [27, '23yueyuetuan_55d9f8a252.pairs'],
#  [27, 'linyuqi_f9f594d7d1.pairs'],
#  [27, 'mariowu_a3bfd6ba5b.pairs'],
#  [26, 'wangzhengkai_cdb65963f6.pairs'],
#  [26, 'tingshuoajianyeyaoshengrile_80034731c9.pairs'],
#  [26, 'wangtinghui_c421438caf.pairs'],
#  [26, 'johnwang_2360c07be8.pairs'],
#  [26, 'zhouliangyan_6389201b75.pairs'],
#  [26, 'baokuayidie_8b66ff3667.pairs'],
#  [26, 'ioannisragusis_0283f5d9d6.pairs'],
#  [26, 'chibiandanglema_d2647c0863.pairs'],
#  [26, 'chenqianhui_c37c3aba54.pairs'],
#  [26, 'chouchouwuzhandoutuoluodashi_a02b77930e.pairs'],
#  [25, 'ourenjun_10e1597000.pairs'],
#  [25, 'lillianhuang_e1b4641d0c.pairs'],
#  [25, 'xiechengyou_087c9fff43.pairs'],
#  [25, 'facebookyonghuhuangyixuanhelutingxuan_04d0bf4c90.pairs'],
#  [25, 'xiecien_f6787c20bc.pairs'],
#  [25, 'chiaichengxupinhanchengcaixuanhehuangliwen_9979c0a509.pairs'],
#  [25, 'gexuan_4ad9fd30cf.pairs'],
#  [25, 'houzongyou_25cd1db753.pairs'],
#  [24, 'wangnaixiang_da302bbd5d.pairs'],
#  [24, 'baimingxuan_8473c0ce78.pairs'],
#  [24, 'chenmin_0ed5857778.pairs'],
#  [24, 'chenqianyu_84de708100.pairs'],
#  [24, 'chhsh_7e6fb55c31.pairs'],
#  [24, 'wangrenhong_fca2f7fc74.pairs'],
#  [24, 'oopproject_1fe167983e.pairs'],
#  [24, 'gongguanbu_121c835341.pairs'],
#  [24, 'leizongda_4be334ad6b.pairs'],
#  [24, 'stevenxu_43c7fb803e.pairs'],
#  [24, 'vincentyau_facc1b27a7.pairs'],
#  [24, 'mingtu_71dcc30bc1.pairs'],
#  [24, 'houzongyouhehongnianqi_c71ee11b6d.pairs'],
#  [24, 'yinanchen_c13c2ec03e.pairs'],
#  [23, 'fenhongsedemimi_d9f5f58682.pairs'],
#  [23, 'tumamajiaodaiashuxiaoxinbaileishaoen_14470129be.pairs'],
#  [23, 'mingcianhongsimonfellnerjohanmartenssonheqita6ren_b039304a12.pairs'],
#  [23, 'guoshengjia_2debaaafa9.pairs'],
#  [23, 'liyingxun_5a51bebb02.pairs'],
#  [23, 'shizongyou_6bc356046e.pairs'],
#  [23, 'shengfubu_c59b8d99d4.pairs'],
#  [23, 'taidabeinuzilanqiusai_b64746c133.pairs'],
#  [22, 'tsaipingkuocyriaquebruezheerikashimizu_33c6068be1.pairs'],
#  [22, 'yundonghuibahexd_46bc6d2c24.pairs'],
#  [22, 'chenhonglun_7a8f6e08e3.pairs'],
#  [22, 'guobingxuan_d92e0455d9.pairs'],
#  [22, 'yuwanhsuan_78d114e62d.pairs'],
#  [22, 'engengengruichaohuici_3dc8f4e57e.pairs'],
#  [22, 'dingdingjiang_eaefaae770.pairs'],
#  [22, 'chouchouhuhechenhongzhi_a860b626d4.pairs'],
#  [22, 'elsahanpeizhen_ae6bea6644.pairs'],
#  [22, 'tairiqimomingtianxiawuliangdian_2a1d73a82c.pairs'],
#  [22, 'xueshifudatouzhao_7a7e80b2ca.pairs'],
#  [22, '6louapayinlehuodongkongjian_35bf1f3e15.pairs'],
#  [21, 'evahan_908cc8a413.pairs'],
#  [21, 'zhangliyin_e57dd7dba8.pairs'],
#  [21, 'mianhuchouchou_dcc87f2d99.pairs'],
#  [21, 'huangkaixiang_97e3524bb3.pairs'],
#  [21, 'zhuoyouquan_807634788c.pairs'],
#  [21, 'leavliegen_8634d4fa58.pairs'],
#  [21, 'ozchian_7039fd16e1.pairs'],
#  [21, 'linwanqing_d7c829d1fd.pairs'],
#  [21, 'jianyiru_2b2dff5bf0.pairs']]

# %%
sum(all_num)
# Out:
# 109232

# %%
with open('test.json','w') as f1:
    json.dump(QA_pairs,f1)

# %%
with open('processed_messages/AndyChou_a01b7203b6.docs','r') as f1:
    test = json.load(f1)

# %%
with open('processed_messages/AndyChou_a01b7203b6.pairs','r') as f1:
    test1 = json.load(f1)

# %%
len(test1)
# Out:
# 81
